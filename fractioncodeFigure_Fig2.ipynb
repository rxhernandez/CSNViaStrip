# %%
import matplotlib
import matplotlib.pyplot as plt
  
  
fig = plt.figure()
ax = fig.add_subplot(111)
  
rect1 = matplotlib.patches.Rectangle((-200, -100),
                                     600, 200,
                                     color ='green')
  
rect2 = matplotlib.patches.Rectangle((0, 150),
                                     300, 20,
                                     color ='pink')
  
rect3 = matplotlib.patches.Rectangle((-300, -50),
                                     40, 200,
                                     color ='yellow')
  
ax.add_patch(rect1)
ax.add_patch(rect2)
ax.add_patch(rect3)
  
plt.xlim([-400, 400])
plt.ylim([-400, 400])
  
plt.show()

# %%
#This is testing figure

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
  
  
fig = plt.figure()
ax = fig.add_subplot(111)
  
rect1 = matplotlib.patches.Rectangle((250, 250),
                                     1000, 250,
                                     color ='lightgrey')


rect1_1 = matplotlib.patches.Rectangle((500, 250),
                                     250, 250,
                                     color ='mediumaquamarine')


rect2 = matplotlib.patches.Rectangle((250, 750),
                                     1000, 250,
                                     color ='green')

ax.add_patch(rect1)
ax.add_patch(rect1_1)
ax.add_patch(rect2)
#ax.add_patch(rect3)
  
#plt.axis("off") to remove axis     
plt.xlim([0, 2000])
plt.ylim([0, 2000])
# Out:
# (0.0, 2000.0)

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
  
  
fig = plt.figure()
ax = fig.add_subplot(111)
  
rect1 = matplotlib.patches.Rectangle((250, 250),
                                     1750, 250,
                                     color ='lightgrey')

rect1_1 = matplotlib.patches.Rectangle((1750, 250),
                                     250, 250,
                                     color ='mediumaquamarine')

rect2 = matplotlib.patches.Rectangle((250, 750),
                                     1750, 250,
                                     color ='lightgrey')

rect2_1 = matplotlib.patches.Rectangle((1500, 750),
                                     250, 250,
                                     color ='mediumaquamarine')

rect3 = matplotlib.patches.Rectangle((250, 1250),
                                     1750, 250,
                                     color ='lightgrey')

rect3_1 = matplotlib.patches.Rectangle((1250, 1250),
                                     250, 250,
                                     color ='mediumaquamarine')

rect4 = matplotlib.patches.Rectangle((250, 1750),
                                     1750, 250,
                                     color ='lightgrey')

rect4_1 = matplotlib.patches.Rectangle((1000, 1750),
                                     250, 250,
                                     color ='mediumaquamarine')

rect5 = matplotlib.patches.Rectangle((250, 2250),
                                     1750, 250,
                                     color ='lightgrey')

rect5_1 = matplotlib.patches.Rectangle((750, 2250),
                                     250, 250,
                                     color ='mediumaquamarine')

rect6 = matplotlib.patches.Rectangle((250, 2750),
                                     1750, 250,
                                     color ='lightgrey')

rect6_1 = matplotlib.patches.Rectangle((500, 2750),
                                     250, 250,
                                     color ='mediumaquamarine')

rect7 = matplotlib.patches.Rectangle((250, 3250),
                                     1750, 250,
                                     color ='lightgrey')

rect7_1 = matplotlib.patches.Rectangle((250, 3250),
                                     250, 250,
                                     color ='mediumaquamarine')

#rect1_1 = matplotlib.patches.Rectangle((750, 250),
#                                     1000, 250,
#                                     color ='mediumaquamarine')
#rect1_1 = matplotlib.patches.Rectangle((1000, 250),
#                                     1000, 250,
#                                     color ='lightgrey')
#rect1_1 = matplotlib.patches.Rectangle((1250, 250),
#                                     1000, 250,
#                                     color ='lightgrey')
#rect1_1 = matplotlib.patches.Rectangle((500, 250),
#                                     1000, 250,
#                                     color ='lightgrey')
#rect1_1 = matplotlib.patches.Rectangle((500, 250),
#                                     1000, 250,
#                                     color ='mediumaquamarine')




ax.add_patch(rect1)
ax.add_patch(rect1_1)
ax.add_patch(rect2)
ax.add_patch(rect2_1)
ax.add_patch(rect3)
ax.add_patch(rect3_1)
ax.add_patch(rect4)
ax.add_patch(rect4_1)
ax.add_patch(rect5)
ax.add_patch(rect5_1)
ax.add_patch(rect6)
ax.add_patch(rect6_1)
ax.add_patch(rect7)
ax.add_patch(rect7_1)
  
plt.axis("off") #to remove axis


plt.xlim([0, 3500])
plt.ylim([0, 3500])
# Out:
# (0.0, 3500.0)

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

from matplotlib.pyplot import figure

figure(figsize=(8, 8), dpi=300)
  
fig = plt.figure()
ax = fig.add_subplot(111)
  
rect1 = matplotlib.patches.Rectangle((250, 250),
                                     1000, 250,
                                     color ='lightgrey')

rect1_1 = matplotlib.patches.Rectangle((1000, 250),
                                     250, 250,
                                     color ='mediumaquamarine')

rect2 = matplotlib.patches.Rectangle((250, 750),
                                     1000, 250,
                                     color ='lightgrey')

rect2_1 = matplotlib.patches.Rectangle((750, 750),
                                     250, 250,
                                     color ='mediumaquamarine')

rect3 = matplotlib.patches.Rectangle((250, 1250),
                                     1000, 250,
                                     color ='lightgrey')

rect3_1 = matplotlib.patches.Rectangle((500, 1250),
                                     250, 250,
                                     color ='mediumaquamarine')

rect4 = matplotlib.patches.Rectangle((250, 1750),
                                     1000, 250,
                                     color ='lightgrey')

rect4_1 = matplotlib.patches.Rectangle((250, 1750),
                                     250, 250,
                                     color ='mediumaquamarine')



ax.add_patch(rect1)
ax.add_patch(rect1_1)
ax.add_patch(rect2)
ax.add_patch(rect2_1)
ax.add_patch(rect3)
ax.add_patch(rect3_1)
ax.add_patch(rect4)
ax.add_patch(rect4_1)

  
plt.axis("off") #to remove axis


plt.xlim([0, 1500])
plt.ylim([0, 4000])

plt.savefig('Fig2_a.eps')

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
  
from matplotlib.pyplot import figure

figure(figsize=(8, 8), dpi=300)    
  
fig = plt.figure()

ax = fig.add_subplot(111)

#ax.set_title('Ensemble of k fold bags (k=4)')
#ax.set_ylabel('k folds')
  
rect1 = matplotlib.patches.Rectangle((0, 250), 1400, 250, color ='lightgrey')

rect1_1 = matplotlib.patches.Rectangle((1200, 250), 200, 250, color ='mediumaquamarine')

rect2 = matplotlib.patches.Rectangle((0, 750), 1400, 250, color ='lightgrey')

rect2_1 = matplotlib.patches.Rectangle((1000, 750), 200, 250, color ='mediumaquamarine')

rect3 = matplotlib.patches.Rectangle((0, 1250), 1400, 250, color ='lightgrey')

rect3_1 = matplotlib.patches.Rectangle((800, 1250), 200, 250, color ='mediumaquamarine')

rect4 = matplotlib.patches.Rectangle((0, 1750), 1400, 250, color ='lightgrey')

rect4_1 = matplotlib.patches.Rectangle((600, 1750), 200, 250, color ='mediumaquamarine')

rect5 = matplotlib.patches.Rectangle((0, 2250), 1400, 250, color ='lightgrey')

rect5_1 = matplotlib.patches.Rectangle((400, 2250), 200, 250, color ='mediumaquamarine')

rect6 = matplotlib.patches.Rectangle((0, 2750), 1400, 250, color ='lightgrey')

rect6_1 = matplotlib.patches.Rectangle((200, 2750), 200, 250, color ='mediumaquamarine')

rect7 = matplotlib.patches.Rectangle((0, 3250), 1400, 250, color ='lightgrey')

rect7_1 = matplotlib.patches.Rectangle((0, 3260), 200, 250, color ='mediumaquamarine')



ax.add_patch(rect1)
ax.add_patch(rect1_1)
ax.add_patch(rect2)
ax.add_patch(rect2_1)
ax.add_patch(rect3)
ax.add_patch(rect3_1)
ax.add_patch(rect4)
ax.add_patch(rect4_1)
ax.add_patch(rect5)
ax.add_patch(rect5_1)
ax.add_patch(rect6)
ax.add_patch(rect6_1)
ax.add_patch(rect7)
ax.add_patch(rect7_1)

ax.autoscale()
  
plt.axis("off") #to remove axis


plt.xlim([0, 2000])
plt.ylim([0, 4000])

#plt.show()

plt.savefig('A.eps')

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
  
  
fig = plt.figure()
ax = fig.add_subplot(111)
  
rect1 = matplotlib.patches.Rectangle((250, 250),
                                     1000, 250,
                                     color ='lightgrey')

rect1_1 = matplotlib.patches.Rectangle((250, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_2 = matplotlib.patches.Rectangle((273.4375, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_3 = matplotlib.patches.Rectangle((281.25, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_4 = matplotlib.patches.Rectangle((304.6875, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_5 = matplotlib.patches.Rectangle((343.75, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_6 = matplotlib.patches.Rectangle((375, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_7 = matplotlib.patches.Rectangle((390.625, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_8 = matplotlib.patches.Rectangle((414.0625, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_9 = matplotlib.patches.Rectangle((453.125, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_10 = matplotlib.patches.Rectangle((476.5625, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_11 = matplotlib.patches.Rectangle((484.375, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_12 = matplotlib.patches.Rectangle((492.1875, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_13 = matplotlib.patches.Rectangle((500, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_14 = matplotlib.patches.Rectangle((531.25, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_15 = matplotlib.patches.Rectangle((562.5, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_16 = matplotlib.patches.Rectangle((601.5625, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_17 = matplotlib.patches.Rectangle((648.4375, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_18 = matplotlib.patches.Rectangle((687.5, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_19 = matplotlib.patches.Rectangle((750, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_20 = matplotlib.patches.Rectangle((804.6875, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_21 = matplotlib.patches.Rectangle((859.375, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_22 = matplotlib.patches.Rectangle((914.0625, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_23 = matplotlib.patches.Rectangle((968.75, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_24 = matplotlib.patches.Rectangle((1000, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_25 = matplotlib.patches.Rectangle((1023.4375, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_26 = matplotlib.patches.Rectangle((1062.5, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_27 = matplotlib.patches.Rectangle((1085.9375, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_28 = matplotlib.patches.Rectangle((1171.1875, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_29 = matplotlib.patches.Rectangle((1140.625, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_30 = matplotlib.patches.Rectangle((1171.875, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_31 = matplotlib.patches.Rectangle((1203.125, 250), 7.8125, 250, color ='mediumaquamarine')
rect1_32 = matplotlib.patches.Rectangle((1226.5625, 250), 7.8125, 250, color ='mediumaquamarine')












A=[250, 257.8125, 265.625, 273.4375, 281.25, 289.0625, 296.875, 304.6875, 312.5, 320.3125, 328.125, 335.9375, 343.75, 351.5625, 359.375, 367.1875, 375, 382.8125, 390.625, 398.4375, 406.25, 414.0625, 421.875, 429.6875, 437.5, 445.3125, 453.125, 460.9375, 468.75, 476.5625, 484.375, 492.1875]

rect2 = matplotlib.patches.Rectangle((250, 750),
                                     1000, 250,
                                     color ='lightgrey')

rect2_1 = matplotlib.patches.Rectangle((A[0], 750),7.8125, 250,color ='mediumaquamarine')
rect2_2 = matplotlib.patches.Rectangle((A[1], 750),7.8125, 250,color ='mediumaquamarine')
rect2_3 = matplotlib.patches.Rectangle((A[2], 750),7.8125, 250,color ='mediumaquamarine')
rect2_4 = matplotlib.patches.Rectangle((A[3], 750),7.8125, 250,color ='mediumaquamarine')
rect2_5 = matplotlib.patches.Rectangle((A[4], 750),7.8125, 250,color ='mediumaquamarine')
rect2_6 = matplotlib.patches.Rectangle((A[5], 750),7.8125, 250,color ='mediumaquamarine')
rect2_7 = matplotlib.patches.Rectangle((A[6], 750),7.8125, 250,color ='mediumaquamarine')
rect2_8 = matplotlib.patches.Rectangle((A[7], 750),7.8125, 250,color ='mediumaquamarine')
rect2_9 = matplotlib.patches.Rectangle((A[8], 750),7.8125, 250,color ='mediumaquamarine')
rect2_10 = matplotlib.patches.Rectangle((A[9], 750),7.8125, 250,color ='mediumaquamarine')
rect2_11 = matplotlib.patches.Rectangle((A[10], 750),7.8125, 250,color ='mediumaquamarine')
rect2_12 = matplotlib.patches.Rectangle((A[11], 750),7.8125, 250,color ='mediumaquamarine')
rect2_13 = matplotlib.patches.Rectangle((A[12], 750),7.8125, 250,color ='mediumaquamarine')
rect2_14 = matplotlib.patches.Rectangle((A[13], 750),7.8125, 250,color ='mediumaquamarine')
rect2_15 = matplotlib.patches.Rectangle((A[14], 750),7.8125, 250,color ='mediumaquamarine')
rect2_16 = matplotlib.patches.Rectangle((A[15], 750),7.8125, 250,color ='mediumaquamarine')
rect2_17 = matplotlib.patches.Rectangle((A[16], 750),7.8125, 250,color ='mediumaquamarine')
rect2_18 = matplotlib.patches.Rectangle((A[17], 750),7.8125, 250,color ='mediumaquamarine')
rect2_19 = matplotlib.patches.Rectangle((A[18], 750),7.8125, 250,color ='mediumaquamarine')
rect2_20 = matplotlib.patches.Rectangle((A[19], 750),7.8125, 250,color ='mediumaquamarine')
rect2_21 = matplotlib.patches.Rectangle((A[20], 750),7.8125, 250,color ='mediumaquamarine')
rect2_22 = matplotlib.patches.Rectangle((A[21], 750),7.8125, 250,color ='mediumaquamarine')
rect2_23 = matplotlib.patches.Rectangle((A[22], 750),7.8125, 250,color ='mediumaquamarine')
rect2_24 = matplotlib.patches.Rectangle((A[23], 750),7.8125, 250,color ='mediumaquamarine')
rect2_25 = matplotlib.patches.Rectangle((A[24], 750),7.8125, 250,color ='mediumaquamarine')
rect2_26 = matplotlib.patches.Rectangle((A[25], 750),7.8125, 250,color ='mediumaquamarine')
rect2_27 = matplotlib.patches.Rectangle((A[26], 750),7.8125, 250,color ='mediumaquamarine')
rect2_28 = matplotlib.patches.Rectangle((A[27], 750),7.8125, 250,color ='mediumaquamarine')
rect2_29 = matplotlib.patches.Rectangle((A[28], 750),7.8125, 250,color ='mediumaquamarine')
rect2_30 = matplotlib.patches.Rectangle((A[29], 750),7.8125, 250,color ='mediumaquamarine')
rect2_31 = matplotlib.patches.Rectangle((A[30], 750),7.8125, 250,color ='mediumaquamarine')
rect2_32 = matplotlib.patches.Rectangle((A[31], 750),7.8125, 250,color ='mediumaquamarine')


rect3 = matplotlib.patches.Rectangle((250, 1250),
                                     1000, 250,
                                     color ='lightgrey')

rect3_1 = matplotlib.patches.Rectangle((500, 1250),
                                     250, 250,
                                     color ='mediumaquamarine')

rect4 = matplotlib.patches.Rectangle((250, 1750),
                                     1000, 250,
                                     color ='lightgrey')

rect4_1 = matplotlib.patches.Rectangle((250, 1750),
                                     250, 250,
                                     color ='mediumaquamarine')



ax.add_patch(rect1)
ax.add_patch(rect1_1)
ax.add_patch(rect1_2)
ax.add_patch(rect1_3)
ax.add_patch(rect1_4)
ax.add_patch(rect1_5)
ax.add_patch(rect1_6)
ax.add_patch(rect1_7)
ax.add_patch(rect1_8)
ax.add_patch(rect1_9)
ax.add_patch(rect1_10)
ax.add_patch(rect1_11)
ax.add_patch(rect1_12)
ax.add_patch(rect1_13)
ax.add_patch(rect1_14)
ax.add_patch(rect1_15)
ax.add_patch(rect1_16)
ax.add_patch(rect1_17)
ax.add_patch(rect1_18)
ax.add_patch(rect1_19)
ax.add_patch(rect1_20)
ax.add_patch(rect1_21)
ax.add_patch(rect1_22)
ax.add_patch(rect1_23)
ax.add_patch(rect1_24)
ax.add_patch(rect1_25)
ax.add_patch(rect1_26)
ax.add_patch(rect1_27)
ax.add_patch(rect1_28)
ax.add_patch(rect1_29)
ax.add_patch(rect1_30)
ax.add_patch(rect1_31)
ax.add_patch(rect1_32)


ax.add_patch(rect2)
ax.add_patch(rect2_1)
ax.add_patch(rect2_2)
ax.add_patch(rect2_3)
ax.add_patch(rect2_4)
ax.add_patch(rect2_5)
ax.add_patch(rect2_6)
ax.add_patch(rect2_7)
ax.add_patch(rect2_8)
ax.add_patch(rect2_9)
ax.add_patch(rect2_10)
ax.add_patch(rect2_11)
ax.add_patch(rect2_12)
ax.add_patch(rect2_13)
ax.add_patch(rect2_14)
ax.add_patch(rect2_15)
ax.add_patch(rect2_16)
ax.add_patch(rect2_17)
ax.add_patch(rect2_18)
ax.add_patch(rect2_19)
ax.add_patch(rect2_20)
ax.add_patch(rect2_21)
ax.add_patch(rect2_22)
ax.add_patch(rect2_23)
ax.add_patch(rect2_24)
ax.add_patch(rect2_25)
ax.add_patch(rect2_26)
ax.add_patch(rect2_27)
ax.add_patch(rect2_28)
ax.add_patch(rect2_29)
ax.add_patch(rect2_30)
ax.add_patch(rect2_31)
ax.add_patch(rect2_32)





ax.add_patch(rect3)
ax.add_patch(rect3_1)
ax.add_patch(rect4)
ax.add_patch(rect4_1)

  
#plt.axis("off") #to remove axis


plt.xlim([0, 2000])
plt.ylim([0, 2000])
# Out:
# (0.0, 2000.0)

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

from matplotlib.pyplot import figure

figure(figsize=(8, 8), dpi=300)
  
  
fig = plt.figure()
ax = fig.add_subplot(111)
  
rect1 = matplotlib.patches.Rectangle((250, 250),
                                     1000, 250,
                                     color ='lightgrey')

A=[250, 281.25, 304.6875, 335.9375, 367.1875, 375, 414.0625, 453.125, 492.1875, 546.875, 562.5, 601.5625, 609.375, 617.1875, 640.625, 671.875, 734.375, 757.8125, 796.875, 867.1875, 890.625, 914.0625, 992.1875, 1039.0625, 1070.3125, 1171.875, 1187.5, 1203.125, 1210.9375, 1226.5625, 1234.375, 1242.1875]

rect1_1 = matplotlib.patches.Rectangle((A[0], 250),7.8125, 250,color ='mediumaquamarine')
rect1_2 = matplotlib.patches.Rectangle((A[1], 250),7.8125, 250,color ='mediumaquamarine')
rect1_3 = matplotlib.patches.Rectangle((A[2], 250),7.8125, 250,color ='mediumaquamarine')
rect1_4 = matplotlib.patches.Rectangle((A[3], 250),7.8125, 250,color ='mediumaquamarine')
rect1_5 = matplotlib.patches.Rectangle((A[4], 250),7.8125, 250,color ='mediumaquamarine')
rect1_6 = matplotlib.patches.Rectangle((A[5], 250),7.8125, 250,color ='mediumaquamarine')
rect1_7 = matplotlib.patches.Rectangle((A[6], 250),7.8125, 250,color ='mediumaquamarine')
rect1_8 = matplotlib.patches.Rectangle((A[7], 250),7.8125, 250,color ='mediumaquamarine')
rect1_9 = matplotlib.patches.Rectangle((A[8], 250),7.8125, 250,color ='mediumaquamarine')
rect1_10 = matplotlib.patches.Rectangle((A[9], 250),7.8125, 250,color ='mediumaquamarine')
rect1_11 = matplotlib.patches.Rectangle((A[10], 250),7.8125, 250,color ='mediumaquamarine')
rect1_12 = matplotlib.patches.Rectangle((A[11], 250),7.8125, 250,color ='mediumaquamarine')
rect1_13 = matplotlib.patches.Rectangle((A[12], 250),7.8125, 250,color ='mediumaquamarine')
rect1_14 = matplotlib.patches.Rectangle((A[13], 250),7.8125, 250,color ='mediumaquamarine')
rect1_15 = matplotlib.patches.Rectangle((A[14], 250),7.8125, 250,color ='mediumaquamarine')
rect1_16 = matplotlib.patches.Rectangle((A[15], 250),7.8125, 250,color ='mediumaquamarine')
rect1_17 = matplotlib.patches.Rectangle((A[16], 250),7.8125, 250,color ='mediumaquamarine')
rect1_18 = matplotlib.patches.Rectangle((A[17], 250),7.8125, 250,color ='mediumaquamarine')
rect1_19 = matplotlib.patches.Rectangle((A[18], 250),7.8125, 250,color ='mediumaquamarine')
rect1_20 = matplotlib.patches.Rectangle((A[19], 250),7.8125, 250,color ='mediumaquamarine')
rect1_21 = matplotlib.patches.Rectangle((A[20], 250),7.8125, 250,color ='mediumaquamarine')
rect1_22 = matplotlib.patches.Rectangle((A[21], 250),7.8125, 250,color ='mediumaquamarine')
rect1_23 = matplotlib.patches.Rectangle((A[22], 250),7.8125, 250,color ='mediumaquamarine')
rect1_24 = matplotlib.patches.Rectangle((A[23], 250),7.8125, 250,color ='mediumaquamarine')
rect1_25 = matplotlib.patches.Rectangle((A[24], 250),7.8125, 250,color ='mediumaquamarine')
rect1_26 = matplotlib.patches.Rectangle((A[25], 250),7.8125, 250,color ='mediumaquamarine')
rect1_27 = matplotlib.patches.Rectangle((A[26], 250),7.8125, 250,color ='mediumaquamarine')
rect1_28 = matplotlib.patches.Rectangle((A[27], 250),7.8125, 250,color ='mediumaquamarine')
rect1_29 = matplotlib.patches.Rectangle((A[28], 250),7.8125, 250,color ='mediumaquamarine')
rect1_30 = matplotlib.patches.Rectangle((A[29], 250),7.8125, 250,color ='mediumaquamarine')
rect1_31 = matplotlib.patches.Rectangle((A[30], 250),7.8125, 250,color ='mediumaquamarine')
rect1_32 = matplotlib.patches.Rectangle((A[31], 250),7.8125, 250,color ='mediumaquamarine')



rect2 = matplotlib.patches.Rectangle((250, 1250),
                                     1000, 250,
                                     color ='lightgrey')
B=[257.8125, 289.0625, 304.6875, 351.5625, 398.4375, 437.5, 468.75, 492.1875, 532.4375, 554.6875, 601.5625, 632.8125, 679.6875, 710.9375, 804.6875, 820.3125, 835.9375, 859.375, 890.625, 914.0625, 968.75, 1000, 1015.625, 1046.875, 1093.75, 1109.375, 1125, 1148.4375, 1179.6875, 1195,3125, 1218.75, 1234.375]

rect2_1 = matplotlib.patches.Rectangle((B[0], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_2 = matplotlib.patches.Rectangle((B[1], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_3 = matplotlib.patches.Rectangle((B[2], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_4 = matplotlib.patches.Rectangle((B[3], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_5 = matplotlib.patches.Rectangle((B[4], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_6 = matplotlib.patches.Rectangle((B[5], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_7 = matplotlib.patches.Rectangle((B[6], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_8 = matplotlib.patches.Rectangle((B[7], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_9 = matplotlib.patches.Rectangle((B[8], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_10 = matplotlib.patches.Rectangle((B[9], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_11 = matplotlib.patches.Rectangle((B[10], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_12 = matplotlib.patches.Rectangle((B[11], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_13 = matplotlib.patches.Rectangle((B[12], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_14 = matplotlib.patches.Rectangle((B[13], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_15 = matplotlib.patches.Rectangle((B[14], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_16 = matplotlib.patches.Rectangle((B[15], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_17 = matplotlib.patches.Rectangle((B[16], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_18 = matplotlib.patches.Rectangle((B[17], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_19 = matplotlib.patches.Rectangle((B[18], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_20 = matplotlib.patches.Rectangle((B[19], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_21 = matplotlib.patches.Rectangle((B[20], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_22 = matplotlib.patches.Rectangle((B[21], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_23 = matplotlib.patches.Rectangle((B[22], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_24 = matplotlib.patches.Rectangle((B[23], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_25 = matplotlib.patches.Rectangle((B[24], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_26 = matplotlib.patches.Rectangle((B[25], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_27 = matplotlib.patches.Rectangle((B[26], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_28 = matplotlib.patches.Rectangle((B[27], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_29 = matplotlib.patches.Rectangle((B[28], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_30 = matplotlib.patches.Rectangle((B[29], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_31 = matplotlib.patches.Rectangle((B[30], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_32 = matplotlib.patches.Rectangle((B[31], 1250),7.8125, 250,color ='mediumaquamarine')


#rect3 = matplotlib.patches.Rectangle((250, 1250),
#                                     1000, 250,
#                                     color ='lightgrey')

#rect3_1 = matplotlib.patches.Rectangle((500, 1250),
#                                     250, 250,
#                                     color ='mediumaquamarine')

rect3 = matplotlib.patches.Rectangle((250, 1750),
                                     1000, 250,
                                     color ='lightgrey')



B=[273.4375, 281.25, 304.6875, 320.3125, 367.1875, 390.625, 429.6875, 453.125, 484.375, 500, 531.25, 578.125, 617.1875, 648.4375, 664.0625, 703.125, 726.5625, 500, 773.4375, 781.25, 789.0625, 812.5, 843.75, 867.1875, 898.4375, 921.875, 953.125, 984.375, 1023.4375, 1070.3125, 1156.25, 1210.9375]

rect3_1 = matplotlib.patches.Rectangle((B[0], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_2 = matplotlib.patches.Rectangle((B[1], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_3 = matplotlib.patches.Rectangle((B[2], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_4 = matplotlib.patches.Rectangle((B[3], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_5 = matplotlib.patches.Rectangle((B[4], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_6 = matplotlib.patches.Rectangle((B[5], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_7 = matplotlib.patches.Rectangle((B[6], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_8 = matplotlib.patches.Rectangle((B[7], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_9 = matplotlib.patches.Rectangle((B[8], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_10 = matplotlib.patches.Rectangle((B[9], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_11 = matplotlib.patches.Rectangle((B[10], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_12 = matplotlib.patches.Rectangle((B[11], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_13 = matplotlib.patches.Rectangle((B[12], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_14 = matplotlib.patches.Rectangle((B[13], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_15 = matplotlib.patches.Rectangle((B[14], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_16 = matplotlib.patches.Rectangle((B[15], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_17 = matplotlib.patches.Rectangle((B[16], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_18 = matplotlib.patches.Rectangle((B[17], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_19 = matplotlib.patches.Rectangle((B[18], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_20 = matplotlib.patches.Rectangle((B[19], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_21 = matplotlib.patches.Rectangle((B[20], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_22 = matplotlib.patches.Rectangle((B[21], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_23 = matplotlib.patches.Rectangle((B[22], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_24 = matplotlib.patches.Rectangle((B[23], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_25 = matplotlib.patches.Rectangle((B[24], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_26 = matplotlib.patches.Rectangle((B[25], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_27 = matplotlib.patches.Rectangle((B[26], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_28 = matplotlib.patches.Rectangle((B[27], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_29 = matplotlib.patches.Rectangle((B[28], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_30 = matplotlib.patches.Rectangle((B[29], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_31 = matplotlib.patches.Rectangle((B[30], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_32 = matplotlib.patches.Rectangle((B[31], 1750),7.8125, 250,color ='mediumaquamarine')

rect4 = matplotlib.patches.Rectangle((250, 2250),
                                     1000, 250,
                                     color ='lightgrey')

B=[265.625, 281.25, 328.125, 343.75, 359.375, 406.25, 421.875, 445.3125, 460.9375, 476.5625, 507.8125, 515.625, 539.0625, 546.875, 562.5, 601.5625, 640.625, 671.875, 695.3125, 718.75, 742.1875, 765.625, 796.875, 820.3125, 851.5625, 929.6875, 976.5625, 1031.25, 1085.9375, 1132.8125, 1195.3125, 1218.75]

rect4_1 = matplotlib.patches.Rectangle((B[0], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_2 = matplotlib.patches.Rectangle((B[1], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_3 = matplotlib.patches.Rectangle((B[2], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_4 = matplotlib.patches.Rectangle((B[3], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_5 = matplotlib.patches.Rectangle((B[4], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_6 = matplotlib.patches.Rectangle((B[5], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_7 = matplotlib.patches.Rectangle((B[6], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_8 = matplotlib.patches.Rectangle((B[7], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_9 = matplotlib.patches.Rectangle((B[8], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_10 = matplotlib.patches.Rectangle((B[9], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_11 = matplotlib.patches.Rectangle((B[10], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_12 = matplotlib.patches.Rectangle((B[11], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_13 = matplotlib.patches.Rectangle((B[12], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_14 = matplotlib.patches.Rectangle((B[13], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_15 = matplotlib.patches.Rectangle((B[14], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_16 = matplotlib.patches.Rectangle((B[15], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_17 = matplotlib.patches.Rectangle((B[16], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_18 = matplotlib.patches.Rectangle((B[17], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_19 = matplotlib.patches.Rectangle((B[18], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_20 = matplotlib.patches.Rectangle((B[19], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_21 = matplotlib.patches.Rectangle((B[20], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_22 = matplotlib.patches.Rectangle((B[21], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_23 = matplotlib.patches.Rectangle((B[22], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_24 = matplotlib.patches.Rectangle((B[23], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_25 = matplotlib.patches.Rectangle((B[24], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_26 = matplotlib.patches.Rectangle((B[25], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_27 = matplotlib.patches.Rectangle((B[26], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_28 = matplotlib.patches.Rectangle((B[27], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_29 = matplotlib.patches.Rectangle((B[28], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_30 = matplotlib.patches.Rectangle((B[29], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_31 = matplotlib.patches.Rectangle((B[30], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_32 = matplotlib.patches.Rectangle((B[31], 2250),7.8125, 250,color ='mediumaquamarine')

rect5 = matplotlib.patches.Rectangle((250, 2750),
                                     1000, 250,
                                     color ='lightgrey')

B=[296.875, 312.5, 328.125, 382.8125, 406.25, 437.5, 460.9375, 476.5625, 523.4375, 554.6875, 585.9375, 625, 656.25, 687.5, 734.375, 835.9375, 875, 898.4375, 906.25, 937.5, 968.75, 992.1875, 1023.4375, 1039.0625, 1054.6875, 1070.3125, 1109.375, 1140.625, 1164.0625, 1179.6875, 1203.125, 1234.375]
rect5_1 = matplotlib.patches.Rectangle((B[0], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_2 = matplotlib.patches.Rectangle((B[1], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_3 = matplotlib.patches.Rectangle((B[2], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_4 = matplotlib.patches.Rectangle((B[3], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_5 = matplotlib.patches.Rectangle((B[4], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_6 = matplotlib.patches.Rectangle((B[5], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_7 = matplotlib.patches.Rectangle((B[6], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_8 = matplotlib.patches.Rectangle((B[7], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_9 = matplotlib.patches.Rectangle((B[8], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_10 = matplotlib.patches.Rectangle((B[9], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_11 = matplotlib.patches.Rectangle((B[10], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_12 = matplotlib.patches.Rectangle((B[11], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_13 = matplotlib.patches.Rectangle((B[12], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_14 = matplotlib.patches.Rectangle((B[13], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_15 = matplotlib.patches.Rectangle((B[14], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_16 = matplotlib.patches.Rectangle((B[15], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_17 = matplotlib.patches.Rectangle((B[16], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_18 = matplotlib.patches.Rectangle((B[17], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_19 = matplotlib.patches.Rectangle((B[18], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_20 = matplotlib.patches.Rectangle((B[19], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_21 = matplotlib.patches.Rectangle((B[20], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_22 = matplotlib.patches.Rectangle((B[21], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_23 = matplotlib.patches.Rectangle((B[22], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_24 = matplotlib.patches.Rectangle((B[23], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_25 = matplotlib.patches.Rectangle((B[24], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_26 = matplotlib.patches.Rectangle((B[25], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_27 = matplotlib.patches.Rectangle((B[26], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_28 = matplotlib.patches.Rectangle((B[27], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_29 = matplotlib.patches.Rectangle((B[28], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_30 = matplotlib.patches.Rectangle((B[29], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_31 = matplotlib.patches.Rectangle((B[30], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_32 = matplotlib.patches.Rectangle((B[31], 2750),7.8125, 250,color ='mediumaquamarine')





ax.add_patch(rect1)
ax.add_patch(rect1_1)
ax.add_patch(rect1_2)
ax.add_patch(rect1_3)
ax.add_patch(rect1_4)
ax.add_patch(rect1_5)
ax.add_patch(rect1_6)
ax.add_patch(rect1_7)
ax.add_patch(rect1_8)
ax.add_patch(rect1_9)
ax.add_patch(rect1_10)
ax.add_patch(rect1_11)
ax.add_patch(rect1_12)
ax.add_patch(rect1_13)
ax.add_patch(rect1_14)
ax.add_patch(rect1_15)
ax.add_patch(rect1_16)
ax.add_patch(rect1_17)
ax.add_patch(rect1_18)
ax.add_patch(rect1_19)
ax.add_patch(rect1_20)
ax.add_patch(rect1_21)
ax.add_patch(rect1_22)
ax.add_patch(rect1_23)
ax.add_patch(rect1_24)
ax.add_patch(rect1_25)
ax.add_patch(rect1_26)
ax.add_patch(rect1_27)
ax.add_patch(rect1_28)
ax.add_patch(rect1_29)
ax.add_patch(rect1_30)
ax.add_patch(rect1_31)
ax.add_patch(rect1_32)


ax.add_patch(rect2)
ax.add_patch(rect2_1)
ax.add_patch(rect2_2)
ax.add_patch(rect2_3)
ax.add_patch(rect2_4)
ax.add_patch(rect2_5)
ax.add_patch(rect2_6)
ax.add_patch(rect2_7)
ax.add_patch(rect2_8)
ax.add_patch(rect2_9)
ax.add_patch(rect2_10)
ax.add_patch(rect2_11)
ax.add_patch(rect2_12)
ax.add_patch(rect2_13)
ax.add_patch(rect2_14)
ax.add_patch(rect2_15)
ax.add_patch(rect2_16)
ax.add_patch(rect2_17)
ax.add_patch(rect2_18)
ax.add_patch(rect2_19)
ax.add_patch(rect2_20)
ax.add_patch(rect2_21)
ax.add_patch(rect2_22)
ax.add_patch(rect2_23)
ax.add_patch(rect2_24)
ax.add_patch(rect2_25)
ax.add_patch(rect2_26)
ax.add_patch(rect2_27)
ax.add_patch(rect2_28)
ax.add_patch(rect2_29)
ax.add_patch(rect2_30)
ax.add_patch(rect2_31)
ax.add_patch(rect2_32)

ax.add_patch(rect3)
ax.add_patch(rect3_1)
ax.add_patch(rect3_2)
ax.add_patch(rect3_3)
ax.add_patch(rect3_4)
ax.add_patch(rect3_5)
ax.add_patch(rect3_6)
ax.add_patch(rect3_7)
ax.add_patch(rect3_8)
ax.add_patch(rect3_9)
ax.add_patch(rect3_10)
ax.add_patch(rect3_11)
ax.add_patch(rect3_12)
ax.add_patch(rect3_13)
ax.add_patch(rect3_14)
ax.add_patch(rect3_15)
ax.add_patch(rect3_16)
ax.add_patch(rect3_17)
ax.add_patch(rect3_18)
ax.add_patch(rect3_19)
ax.add_patch(rect3_20)
ax.add_patch(rect3_21)
ax.add_patch(rect3_22)
ax.add_patch(rect3_23)
ax.add_patch(rect3_24)
ax.add_patch(rect3_25)
ax.add_patch(rect3_26)
ax.add_patch(rect3_27)
ax.add_patch(rect3_28)
ax.add_patch(rect3_29)
ax.add_patch(rect3_30)
ax.add_patch(rect3_31)
ax.add_patch(rect3_32)

ax.add_patch(rect4)
ax.add_patch(rect4_1)
ax.add_patch(rect4_2)
ax.add_patch(rect4_3)
ax.add_patch(rect4_4)
ax.add_patch(rect4_5)
ax.add_patch(rect4_6)
ax.add_patch(rect4_7)
ax.add_patch(rect4_8)
ax.add_patch(rect4_9)
ax.add_patch(rect4_10)
ax.add_patch(rect4_11)
ax.add_patch(rect4_12)
ax.add_patch(rect4_13)
ax.add_patch(rect4_14)
ax.add_patch(rect4_15)
ax.add_patch(rect4_16)
ax.add_patch(rect4_17)
ax.add_patch(rect4_18)
ax.add_patch(rect4_19)
ax.add_patch(rect4_20)
ax.add_patch(rect4_21)
ax.add_patch(rect4_22)
ax.add_patch(rect4_23)
ax.add_patch(rect4_24)
ax.add_patch(rect4_25)
ax.add_patch(rect4_26)
ax.add_patch(rect4_27)
ax.add_patch(rect4_28)
ax.add_patch(rect4_29)
ax.add_patch(rect4_30)
ax.add_patch(rect4_31)
ax.add_patch(rect4_32)

ax.add_patch(rect5)
ax.add_patch(rect5_1)
ax.add_patch(rect5_2)
ax.add_patch(rect5_3)
ax.add_patch(rect5_4)
ax.add_patch(rect5_5)
ax.add_patch(rect5_6)
ax.add_patch(rect5_7)
ax.add_patch(rect5_8)
ax.add_patch(rect5_9)
ax.add_patch(rect5_10)
ax.add_patch(rect5_11)
ax.add_patch(rect5_12)
ax.add_patch(rect5_13)
ax.add_patch(rect5_14)
ax.add_patch(rect5_15)
ax.add_patch(rect5_16)
ax.add_patch(rect5_17)
ax.add_patch(rect5_18)
ax.add_patch(rect5_19)
ax.add_patch(rect5_20)
ax.add_patch(rect5_21)
ax.add_patch(rect5_22)
ax.add_patch(rect5_23)
ax.add_patch(rect5_24)
ax.add_patch(rect5_25)
ax.add_patch(rect5_26)
ax.add_patch(rect5_27)
ax.add_patch(rect5_28)
ax.add_patch(rect5_29)
ax.add_patch(rect5_30)
ax.add_patch(rect5_31)
ax.add_patch(rect5_32)





#ax.add_patch(rect3)
#ax.add_patch(rect3_1)
#ax.add_patch(rect4)
#ax.add_patch(rect4_1)

  
plt.axis("off") #to remove axis


plt.xlim([0, 2000])
plt.ylim([0, 4000])

plt.savefig("Fig2_b.eps")

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

from matplotlib.pyplot import figure

figure(figsize=(8, 8), dpi=300)
  
  
fig = plt.figure()
ax = fig.add_subplot(111)
  
rect1 = matplotlib.patches.Rectangle((250, 250),
                                     1000, 250,
                                     color ='lightgrey')

A=[250, 281.25, 304.6875, 335.9375, 367.1875, 375, 414.0625, 453.125, 492.1875, 546.875, 562.5, 601.5625, 609.375, 617.1875, 640.625, 671.875, 734.375, 757.8125, 796.875, 867.1875, 890.625, 914.0625, 992.1875, 1039.0625, 1070.3125, 1171.875, 1187.5, 1203.125, 1210.9375, 1226.5625, 1234.375, 1242.1875]

rect1_1 = matplotlib.patches.Rectangle((A[0], 250),7.8125, 250,color ='mediumaquamarine')
rect1_2 = matplotlib.patches.Rectangle((A[1], 250),7.8125, 250,color ='mediumaquamarine')
rect1_3 = matplotlib.patches.Rectangle((A[2], 250),7.8125, 250,color ='mediumaquamarine')
rect1_4 = matplotlib.patches.Rectangle((A[3], 250),7.8125, 250,color ='mediumaquamarine')
rect1_5 = matplotlib.patches.Rectangle((A[4], 250),7.8125, 250,color ='mediumaquamarine')
rect1_6 = matplotlib.patches.Rectangle((A[5], 250),7.8125, 250,color ='mediumaquamarine')
rect1_7 = matplotlib.patches.Rectangle((A[6], 250),7.8125, 250,color ='mediumaquamarine')
rect1_8 = matplotlib.patches.Rectangle((A[7], 250),7.8125, 250,color ='mediumaquamarine')
rect1_9 = matplotlib.patches.Rectangle((A[8], 250),7.8125, 250,color ='mediumaquamarine')
rect1_10 = matplotlib.patches.Rectangle((A[9], 250),7.8125, 250,color ='mediumaquamarine')
rect1_11 = matplotlib.patches.Rectangle((A[10], 250),7.8125, 250,color ='mediumaquamarine')
rect1_12 = matplotlib.patches.Rectangle((A[11], 250),7.8125, 250,color ='mediumaquamarine')
rect1_13 = matplotlib.patches.Rectangle((A[12], 250),7.8125, 250,color ='mediumaquamarine')
rect1_14 = matplotlib.patches.Rectangle((A[13], 250),7.8125, 250,color ='mediumaquamarine')
rect1_15 = matplotlib.patches.Rectangle((A[14], 250),7.8125, 250,color ='mediumaquamarine')
rect1_16 = matplotlib.patches.Rectangle((A[15], 250),7.8125, 250,color ='mediumaquamarine')
rect1_17 = matplotlib.patches.Rectangle((A[16], 250),7.8125, 250,color ='mediumaquamarine')
rect1_18 = matplotlib.patches.Rectangle((A[17], 250),7.8125, 250,color ='mediumaquamarine')
rect1_19 = matplotlib.patches.Rectangle((A[18], 250),7.8125, 250,color ='mediumaquamarine')
rect1_20 = matplotlib.patches.Rectangle((A[19], 250),7.8125, 250,color ='mediumaquamarine')
rect1_21 = matplotlib.patches.Rectangle((A[20], 250),7.8125, 250,color ='mediumaquamarine')
rect1_22 = matplotlib.patches.Rectangle((A[21], 250),7.8125, 250,color ='mediumaquamarine')
rect1_23 = matplotlib.patches.Rectangle((A[22], 250),7.8125, 250,color ='mediumaquamarine')
rect1_24 = matplotlib.patches.Rectangle((A[23], 250),7.8125, 250,color ='mediumaquamarine')
rect1_25 = matplotlib.patches.Rectangle((A[24], 250),7.8125, 250,color ='mediumaquamarine')
rect1_26 = matplotlib.patches.Rectangle((A[25], 250),7.8125, 250,color ='mediumaquamarine')
rect1_27 = matplotlib.patches.Rectangle((A[26], 250),7.8125, 250,color ='mediumaquamarine')
rect1_28 = matplotlib.patches.Rectangle((A[27], 250),7.8125, 250,color ='mediumaquamarine')
rect1_29 = matplotlib.patches.Rectangle((A[28], 250),7.8125, 250,color ='mediumaquamarine')
rect1_30 = matplotlib.patches.Rectangle((A[29], 250),7.8125, 250,color ='mediumaquamarine')
rect1_31 = matplotlib.patches.Rectangle((A[30], 250),7.8125, 250,color ='mediumaquamarine')
rect1_32 = matplotlib.patches.Rectangle((A[31], 250),7.8125, 250,color ='mediumaquamarine')



rect2 = matplotlib.patches.Rectangle((250, 1250),
                                     1000, 250,
                                     color ='lightgrey')
B=[257.8125, 289.0625, 304.6875, 351.5625, 398.4375, 437.5, 468.75, 492.1875, 532.4375, 554.6875, 601.5625, 632.8125, 679.6875, 710.9375, 804.6875, 820.3125, 835.9375, 859.375, 890.625, 914.0625, 968.75, 1000, 1015.625, 1046.875, 1093.75, 1109.375, 1125, 1148.4375, 1179.6875, 1195,3125, 1218.75, 1234.375]

rect2_1 = matplotlib.patches.Rectangle((B[0], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_2 = matplotlib.patches.Rectangle((B[1], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_3 = matplotlib.patches.Rectangle((B[2], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_4 = matplotlib.patches.Rectangle((B[3], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_5 = matplotlib.patches.Rectangle((B[4], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_6 = matplotlib.patches.Rectangle((B[5], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_7 = matplotlib.patches.Rectangle((B[6], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_8 = matplotlib.patches.Rectangle((B[7], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_9 = matplotlib.patches.Rectangle((B[8], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_10 = matplotlib.patches.Rectangle((B[9], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_11 = matplotlib.patches.Rectangle((B[10], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_12 = matplotlib.patches.Rectangle((B[11], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_13 = matplotlib.patches.Rectangle((B[12], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_14 = matplotlib.patches.Rectangle((B[13], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_15 = matplotlib.patches.Rectangle((B[14], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_16 = matplotlib.patches.Rectangle((B[15], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_17 = matplotlib.patches.Rectangle((B[16], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_18 = matplotlib.patches.Rectangle((B[17], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_19 = matplotlib.patches.Rectangle((B[18], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_20 = matplotlib.patches.Rectangle((B[19], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_21 = matplotlib.patches.Rectangle((B[20], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_22 = matplotlib.patches.Rectangle((B[21], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_23 = matplotlib.patches.Rectangle((B[22], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_24 = matplotlib.patches.Rectangle((B[23], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_25 = matplotlib.patches.Rectangle((B[24], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_26 = matplotlib.patches.Rectangle((B[25], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_27 = matplotlib.patches.Rectangle((B[26], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_28 = matplotlib.patches.Rectangle((B[27], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_29 = matplotlib.patches.Rectangle((B[28], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_30 = matplotlib.patches.Rectangle((B[29], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_31 = matplotlib.patches.Rectangle((B[30], 1250),7.8125, 250,color ='mediumaquamarine')
rect2_32 = matplotlib.patches.Rectangle((B[31], 1250),7.8125, 250,color ='mediumaquamarine')


#rect3 = matplotlib.patches.Rectangle((250, 1250),
#                                     1000, 250,
#                                     color ='lightgrey')

#rect3_1 = matplotlib.patches.Rectangle((500, 1250),
#                                     250, 250,
#                                     color ='mediumaquamarine')

rect3 = matplotlib.patches.Rectangle((250, 1750),
                                     1000, 250,
                                     color ='lightgrey')



B=[273.4375, 281.25, 304.6875, 320.3125, 367.1875, 390.625, 429.6875, 453.125, 484.375, 500, 531.25, 578.125, 617.1875, 648.4375, 664.0625, 703.125, 726.5625, 500, 773.4375, 781.25, 789.0625, 812.5, 843.75, 867.1875, 898.4375, 921.875, 953.125, 984.375, 1023.4375, 1070.3125, 1156.25, 1210.9375]

rect3_1 = matplotlib.patches.Rectangle((B[0], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_2 = matplotlib.patches.Rectangle((B[1], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_3 = matplotlib.patches.Rectangle((B[2], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_4 = matplotlib.patches.Rectangle((B[3], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_5 = matplotlib.patches.Rectangle((B[4], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_6 = matplotlib.patches.Rectangle((B[5], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_7 = matplotlib.patches.Rectangle((B[6], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_8 = matplotlib.patches.Rectangle((B[7], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_9 = matplotlib.patches.Rectangle((B[8], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_10 = matplotlib.patches.Rectangle((B[9], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_11 = matplotlib.patches.Rectangle((B[10], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_12 = matplotlib.patches.Rectangle((B[11], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_13 = matplotlib.patches.Rectangle((B[12], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_14 = matplotlib.patches.Rectangle((B[13], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_15 = matplotlib.patches.Rectangle((B[14], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_16 = matplotlib.patches.Rectangle((B[15], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_17 = matplotlib.patches.Rectangle((B[16], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_18 = matplotlib.patches.Rectangle((B[17], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_19 = matplotlib.patches.Rectangle((B[18], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_20 = matplotlib.patches.Rectangle((B[19], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_21 = matplotlib.patches.Rectangle((B[20], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_22 = matplotlib.patches.Rectangle((B[21], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_23 = matplotlib.patches.Rectangle((B[22], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_24 = matplotlib.patches.Rectangle((B[23], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_25 = matplotlib.patches.Rectangle((B[24], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_26 = matplotlib.patches.Rectangle((B[25], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_27 = matplotlib.patches.Rectangle((B[26], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_28 = matplotlib.patches.Rectangle((B[27], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_29 = matplotlib.patches.Rectangle((B[28], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_30 = matplotlib.patches.Rectangle((B[29], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_31 = matplotlib.patches.Rectangle((B[30], 1750),7.8125, 250,color ='mediumaquamarine')
rect3_32 = matplotlib.patches.Rectangle((B[31], 1750),7.8125, 250,color ='mediumaquamarine')

rect4 = matplotlib.patches.Rectangle((250, 2250),
                                     1000, 250,
                                     color ='lightgrey')

B=[265.625, 281.25, 328.125, 343.75, 359.375, 406.25, 421.875, 445.3125, 460.9375, 476.5625, 507.8125, 515.625, 539.0625, 546.875, 562.5, 601.5625, 640.625, 671.875, 695.3125, 718.75, 742.1875, 765.625, 796.875, 820.3125, 851.5625, 929.6875, 976.5625, 1031.25, 1085.9375, 1132.8125, 1195.3125, 1218.75]

rect4_1 = matplotlib.patches.Rectangle((B[0], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_2 = matplotlib.patches.Rectangle((B[1], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_3 = matplotlib.patches.Rectangle((B[2], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_4 = matplotlib.patches.Rectangle((B[3], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_5 = matplotlib.patches.Rectangle((B[4], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_6 = matplotlib.patches.Rectangle((B[5], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_7 = matplotlib.patches.Rectangle((B[6], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_8 = matplotlib.patches.Rectangle((B[7], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_9 = matplotlib.patches.Rectangle((B[8], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_10 = matplotlib.patches.Rectangle((B[9], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_11 = matplotlib.patches.Rectangle((B[10], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_12 = matplotlib.patches.Rectangle((B[11], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_13 = matplotlib.patches.Rectangle((B[12], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_14 = matplotlib.patches.Rectangle((B[13], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_15 = matplotlib.patches.Rectangle((B[14], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_16 = matplotlib.patches.Rectangle((B[15], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_17 = matplotlib.patches.Rectangle((B[16], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_18 = matplotlib.patches.Rectangle((B[17], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_19 = matplotlib.patches.Rectangle((B[18], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_20 = matplotlib.patches.Rectangle((B[19], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_21 = matplotlib.patches.Rectangle((B[20], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_22 = matplotlib.patches.Rectangle((B[21], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_23 = matplotlib.patches.Rectangle((B[22], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_24 = matplotlib.patches.Rectangle((B[23], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_25 = matplotlib.patches.Rectangle((B[24], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_26 = matplotlib.patches.Rectangle((B[25], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_27 = matplotlib.patches.Rectangle((B[26], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_28 = matplotlib.patches.Rectangle((B[27], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_29 = matplotlib.patches.Rectangle((B[28], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_30 = matplotlib.patches.Rectangle((B[29], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_31 = matplotlib.patches.Rectangle((B[30], 2250),7.8125, 250,color ='mediumaquamarine')
rect4_32 = matplotlib.patches.Rectangle((B[31], 2250),7.8125, 250,color ='mediumaquamarine')

rect5 = matplotlib.patches.Rectangle((250, 2750),
                                     1000, 250,
                                     color ='lightgrey')

B=[296.875, 312.5, 328.125, 382.8125, 406.25, 437.5, 460.9375, 476.5625, 523.4375, 554.6875, 585.9375, 625, 656.25, 687.5, 734.375, 835.9375, 875, 898.4375, 906.25, 937.5, 968.75, 992.1875, 1023.4375, 1039.0625, 1054.6875, 1070.3125, 1109.375, 1140.625, 1164.0625, 1179.6875, 1203.125, 1234.375]
rect5_1 = matplotlib.patches.Rectangle((B[0], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_2 = matplotlib.patches.Rectangle((B[1], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_3 = matplotlib.patches.Rectangle((B[2], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_4 = matplotlib.patches.Rectangle((B[3], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_5 = matplotlib.patches.Rectangle((B[4], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_6 = matplotlib.patches.Rectangle((B[5], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_7 = matplotlib.patches.Rectangle((B[6], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_8 = matplotlib.patches.Rectangle((B[7], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_9 = matplotlib.patches.Rectangle((B[8], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_10 = matplotlib.patches.Rectangle((B[9], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_11 = matplotlib.patches.Rectangle((B[10], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_12 = matplotlib.patches.Rectangle((B[11], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_13 = matplotlib.patches.Rectangle((B[12], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_14 = matplotlib.patches.Rectangle((B[13], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_15 = matplotlib.patches.Rectangle((B[14], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_16 = matplotlib.patches.Rectangle((B[15], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_17 = matplotlib.patches.Rectangle((B[16], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_18 = matplotlib.patches.Rectangle((B[17], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_19 = matplotlib.patches.Rectangle((B[18], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_20 = matplotlib.patches.Rectangle((B[19], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_21 = matplotlib.patches.Rectangle((B[20], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_22 = matplotlib.patches.Rectangle((B[21], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_23 = matplotlib.patches.Rectangle((B[22], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_24 = matplotlib.patches.Rectangle((B[23], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_25 = matplotlib.patches.Rectangle((B[24], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_26 = matplotlib.patches.Rectangle((B[25], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_27 = matplotlib.patches.Rectangle((B[26], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_28 = matplotlib.patches.Rectangle((B[27], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_29 = matplotlib.patches.Rectangle((B[28], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_30 = matplotlib.patches.Rectangle((B[29], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_31 = matplotlib.patches.Rectangle((B[30], 2750),7.8125, 250,color ='mediumaquamarine')
rect5_32 = matplotlib.patches.Rectangle((B[31], 2750),7.8125, 250,color ='mediumaquamarine')

rect6 = matplotlib.patches.Rectangle((250, 3250),
                                     1000, 250,
                                     color ='lightgrey')

B=[281.25, 328.125, 359.375, 390.625, 398.4375, 437.5, 476.5625, 500, 539.75, 656.25, 671.875, 718.75, 726.5625, 734.375, 757.8125, 796.875, 835.9375, 843.75, 859.375, 906.25, 921.875, 953.125, 992.1875, 1000, 1054.6875, 1085.9375, 1117.1875, 1156.25, 1195.3125, 1210.9375, 1234.375, 1242.1875]
rect6_1 = matplotlib.patches.Rectangle((B[0], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_2 = matplotlib.patches.Rectangle((B[1], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_3 = matplotlib.patches.Rectangle((B[2], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_4 = matplotlib.patches.Rectangle((B[3], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_5 = matplotlib.patches.Rectangle((B[4], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_6 = matplotlib.patches.Rectangle((B[5], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_7 = matplotlib.patches.Rectangle((B[6], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_8 = matplotlib.patches.Rectangle((B[7], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_9 = matplotlib.patches.Rectangle((B[8], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_10 = matplotlib.patches.Rectangle((B[9],  3250),7.8125, 250,color ='mediumaquamarine')
rect6_11 = matplotlib.patches.Rectangle((B[10], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_12 = matplotlib.patches.Rectangle((B[11], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_13 = matplotlib.patches.Rectangle((B[12], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_14 = matplotlib.patches.Rectangle((B[13], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_15 = matplotlib.patches.Rectangle((B[14], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_16 = matplotlib.patches.Rectangle((B[15], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_17 = matplotlib.patches.Rectangle((B[16], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_18 = matplotlib.patches.Rectangle((B[17], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_19 = matplotlib.patches.Rectangle((B[18], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_20 = matplotlib.patches.Rectangle((B[19], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_21 = matplotlib.patches.Rectangle((B[20], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_22 = matplotlib.patches.Rectangle((B[21], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_23 = matplotlib.patches.Rectangle((B[22], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_24 = matplotlib.patches.Rectangle((B[23], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_25 = matplotlib.patches.Rectangle((B[24], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_26 = matplotlib.patches.Rectangle((B[25], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_27 = matplotlib.patches.Rectangle((B[26], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_28 = matplotlib.patches.Rectangle((B[27], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_29 = matplotlib.patches.Rectangle((B[28], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_30 = matplotlib.patches.Rectangle((B[29], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_31 = matplotlib.patches.Rectangle((B[30], 3250),7.8125, 250,color ='mediumaquamarine')
rect6_32 = matplotlib.patches.Rectangle((B[31], 3250),7.8125, 250,color ='mediumaquamarine')


rect7 = matplotlib.patches.Rectangle((250, 3750),
                                     1000, 250,
                                     color ='lightgrey')

B=[257.8125, 289.0625, 320.3125, 351.5625, 390.625, 414.0625, 421.875, 453.125, 476.5625, 484.375, 531.25, 562.5, 578.125, 617.1875, 656.25, 703.125, 773.4375, 843.75, 875, 914.0625, 953.125, 976.5625, 1023.4375, 1054.6875, 1085.9375, 1093.75, 1101.5625, 1132.8125, 1164.0625, 1187.5, 1203.125, 1242.1875]
rect7_1 = matplotlib.patches.Rectangle((B[0], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_2 = matplotlib.patches.Rectangle((B[1], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_3 = matplotlib.patches.Rectangle((B[2], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_4 = matplotlib.patches.Rectangle((B[3], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_5 = matplotlib.patches.Rectangle((B[4], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_6 = matplotlib.patches.Rectangle((B[5], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_7 = matplotlib.patches.Rectangle((B[6], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_8 = matplotlib.patches.Rectangle((B[7], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_9 = matplotlib.patches.Rectangle((B[8], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_10 = matplotlib.patches.Rectangle((B[9],  3750),7.8125, 250,color ='mediumaquamarine')
rect7_11 = matplotlib.patches.Rectangle((B[10], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_12 = matplotlib.patches.Rectangle((B[11], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_13 = matplotlib.patches.Rectangle((B[12], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_14 = matplotlib.patches.Rectangle((B[13], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_15 = matplotlib.patches.Rectangle((B[14], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_16 = matplotlib.patches.Rectangle((B[15], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_17 = matplotlib.patches.Rectangle((B[16], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_18 = matplotlib.patches.Rectangle((B[17], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_19 = matplotlib.patches.Rectangle((B[18], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_20 = matplotlib.patches.Rectangle((B[19], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_21 = matplotlib.patches.Rectangle((B[20], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_22 = matplotlib.patches.Rectangle((B[21], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_23 = matplotlib.patches.Rectangle((B[22], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_24 = matplotlib.patches.Rectangle((B[23], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_25 = matplotlib.patches.Rectangle((B[24], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_26 = matplotlib.patches.Rectangle((B[25], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_27 = matplotlib.patches.Rectangle((B[26], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_28 = matplotlib.patches.Rectangle((B[27], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_29 = matplotlib.patches.Rectangle((B[28], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_30 = matplotlib.patches.Rectangle((B[29], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_31 = matplotlib.patches.Rectangle((B[30], 3750),7.8125, 250,color ='mediumaquamarine')
rect7_32 = matplotlib.patches.Rectangle((B[31], 3750),7.8125, 250,color ='mediumaquamarine')




ax.add_patch(rect1)
ax.add_patch(rect1_1)
ax.add_patch(rect1_2)
ax.add_patch(rect1_3)
ax.add_patch(rect1_4)
ax.add_patch(rect1_5)
ax.add_patch(rect1_6)
ax.add_patch(rect1_7)
ax.add_patch(rect1_8)
ax.add_patch(rect1_9)
ax.add_patch(rect1_10)
ax.add_patch(rect1_11)
ax.add_patch(rect1_12)
ax.add_patch(rect1_13)
ax.add_patch(rect1_14)
ax.add_patch(rect1_15)
ax.add_patch(rect1_16)
ax.add_patch(rect1_17)
ax.add_patch(rect1_18)
ax.add_patch(rect1_19)
ax.add_patch(rect1_20)
ax.add_patch(rect1_21)
ax.add_patch(rect1_22)
ax.add_patch(rect1_23)
ax.add_patch(rect1_24)
ax.add_patch(rect1_25)
ax.add_patch(rect1_26)
ax.add_patch(rect1_27)
ax.add_patch(rect1_28)
ax.add_patch(rect1_29)
ax.add_patch(rect1_30)
ax.add_patch(rect1_31)
ax.add_patch(rect1_32)


ax.add_patch(rect2)
ax.add_patch(rect2_1)
ax.add_patch(rect2_2)
ax.add_patch(rect2_3)
ax.add_patch(rect2_4)
ax.add_patch(rect2_5)
ax.add_patch(rect2_6)
ax.add_patch(rect2_7)
ax.add_patch(rect2_8)
ax.add_patch(rect2_9)
ax.add_patch(rect2_10)
ax.add_patch(rect2_11)
ax.add_patch(rect2_12)
ax.add_patch(rect2_13)
ax.add_patch(rect2_14)
ax.add_patch(rect2_15)
ax.add_patch(rect2_16)
ax.add_patch(rect2_17)
ax.add_patch(rect2_18)
ax.add_patch(rect2_19)
ax.add_patch(rect2_20)
ax.add_patch(rect2_21)
ax.add_patch(rect2_22)
ax.add_patch(rect2_23)
ax.add_patch(rect2_24)
ax.add_patch(rect2_25)
ax.add_patch(rect2_26)
ax.add_patch(rect2_27)
ax.add_patch(rect2_28)
ax.add_patch(rect2_29)
ax.add_patch(rect2_30)
ax.add_patch(rect2_31)
ax.add_patch(rect2_32)

ax.add_patch(rect3)
ax.add_patch(rect3_1)
ax.add_patch(rect3_2)
ax.add_patch(rect3_3)
ax.add_patch(rect3_4)
ax.add_patch(rect3_5)
ax.add_patch(rect3_6)
ax.add_patch(rect3_7)
ax.add_patch(rect3_8)
ax.add_patch(rect3_9)
ax.add_patch(rect3_10)
ax.add_patch(rect3_11)
ax.add_patch(rect3_12)
ax.add_patch(rect3_13)
ax.add_patch(rect3_14)
ax.add_patch(rect3_15)
ax.add_patch(rect3_16)
ax.add_patch(rect3_17)
ax.add_patch(rect3_18)
ax.add_patch(rect3_19)
ax.add_patch(rect3_20)
ax.add_patch(rect3_21)
ax.add_patch(rect3_22)
ax.add_patch(rect3_23)
ax.add_patch(rect3_24)
ax.add_patch(rect3_25)
ax.add_patch(rect3_26)
ax.add_patch(rect3_27)
ax.add_patch(rect3_28)
ax.add_patch(rect3_29)
ax.add_patch(rect3_30)
ax.add_patch(rect3_31)
ax.add_patch(rect3_32)

ax.add_patch(rect4)
ax.add_patch(rect4_1)
ax.add_patch(rect4_2)
ax.add_patch(rect4_3)
ax.add_patch(rect4_4)
ax.add_patch(rect4_5)
ax.add_patch(rect4_6)
ax.add_patch(rect4_7)
ax.add_patch(rect4_8)
ax.add_patch(rect4_9)
ax.add_patch(rect4_10)
ax.add_patch(rect4_11)
ax.add_patch(rect4_12)
ax.add_patch(rect4_13)
ax.add_patch(rect4_14)
ax.add_patch(rect4_15)
ax.add_patch(rect4_16)
ax.add_patch(rect4_17)
ax.add_patch(rect4_18)
ax.add_patch(rect4_19)
ax.add_patch(rect4_20)
ax.add_patch(rect4_21)
ax.add_patch(rect4_22)
ax.add_patch(rect4_23)
ax.add_patch(rect4_24)
ax.add_patch(rect4_25)
ax.add_patch(rect4_26)
ax.add_patch(rect4_27)
ax.add_patch(rect4_28)
ax.add_patch(rect4_29)
ax.add_patch(rect4_30)
ax.add_patch(rect4_31)
ax.add_patch(rect4_32)

ax.add_patch(rect5)
ax.add_patch(rect5_1)
ax.add_patch(rect5_2)
ax.add_patch(rect5_3)
ax.add_patch(rect5_4)
ax.add_patch(rect5_5)
ax.add_patch(rect5_6)
ax.add_patch(rect5_7)
ax.add_patch(rect5_8)
ax.add_patch(rect5_9)
ax.add_patch(rect5_10)
ax.add_patch(rect5_11)
ax.add_patch(rect5_12)
ax.add_patch(rect5_13)
ax.add_patch(rect5_14)
ax.add_patch(rect5_15)
ax.add_patch(rect5_16)
ax.add_patch(rect5_17)
ax.add_patch(rect5_18)
ax.add_patch(rect5_19)
ax.add_patch(rect5_20)
ax.add_patch(rect5_21)
ax.add_patch(rect5_22)
ax.add_patch(rect5_23)
ax.add_patch(rect5_24)
ax.add_patch(rect5_25)
ax.add_patch(rect5_26)
ax.add_patch(rect5_27)
ax.add_patch(rect5_28)
ax.add_patch(rect5_29)
ax.add_patch(rect5_30)
ax.add_patch(rect5_31)
ax.add_patch(rect5_32)

ax.add_patch(rect6)
ax.add_patch(rect6_1)
ax.add_patch(rect6_2)
ax.add_patch(rect6_3)
ax.add_patch(rect6_4)
ax.add_patch(rect6_5)
ax.add_patch(rect6_6)
ax.add_patch(rect6_7)
ax.add_patch(rect6_8)
ax.add_patch(rect6_9)
ax.add_patch(rect6_10)
ax.add_patch(rect6_11)
ax.add_patch(rect6_12)
ax.add_patch(rect6_13)
ax.add_patch(rect6_14)
ax.add_patch(rect6_15)
ax.add_patch(rect6_16)
ax.add_patch(rect6_17)
ax.add_patch(rect6_18)
ax.add_patch(rect6_19)
ax.add_patch(rect6_20)
ax.add_patch(rect6_21)
ax.add_patch(rect6_22)
ax.add_patch(rect6_23)
ax.add_patch(rect6_24)
ax.add_patch(rect6_25)
ax.add_patch(rect6_26)
ax.add_patch(rect6_27)
ax.add_patch(rect6_28)
ax.add_patch(rect6_29)
ax.add_patch(rect6_30)
ax.add_patch(rect6_31)
ax.add_patch(rect6_32)

ax.add_patch(rect7)
ax.add_patch(rect7_1)
ax.add_patch(rect7_2)
ax.add_patch(rect7_3)
ax.add_patch(rect7_4)
ax.add_patch(rect7_5)
ax.add_patch(rect7_6)
ax.add_patch(rect7_7)
ax.add_patch(rect7_8)
ax.add_patch(rect7_9)
ax.add_patch(rect7_10)
ax.add_patch(rect7_11)
ax.add_patch(rect7_12)
ax.add_patch(rect7_13)
ax.add_patch(rect7_14)
ax.add_patch(rect7_15)
ax.add_patch(rect7_16)
ax.add_patch(rect7_17)
ax.add_patch(rect7_18)
ax.add_patch(rect7_19)
ax.add_patch(rect7_20)
ax.add_patch(rect7_21)
ax.add_patch(rect7_22)
ax.add_patch(rect7_23)
ax.add_patch(rect7_24)
ax.add_patch(rect7_25)
ax.add_patch(rect7_26)
ax.add_patch(rect7_27)
ax.add_patch(rect7_28)
ax.add_patch(rect7_29)
ax.add_patch(rect7_30)
ax.add_patch(rect7_31)
ax.add_patch(rect7_32)



#ax.add_patch(rect3)
#ax.add_patch(rect3_1)
#ax.add_patch(rect4)
#ax.add_patch(rect4_1)

  
plt.axis("off") #to remove axis


plt.xlim([0, 2000])
plt.ylim([0, 4000])

plt.savefig("Fig2_e.eps")
