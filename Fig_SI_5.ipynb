# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
matplotlib.rcParams.update({'font.size': 22})
#plt.rcParams["font.family"] = "Times New Roman"

plt.rcParams["font.family"] = "Arial"

# %%
labels = ['LCP1', 'LCP2', 'LCP3', 'LCP4', 'LCP5', 'LCP6','LCP7', 'LCP8', 'LCP9', 'LCP10', 'ND1', 'ND2','ND3', 'ND4', 'ND5', 'ND6', 'ND7', 'ND8']
k_1 = [0.057, 0.014, -0.018, -0.025, -0.036, 0.044, -0.005, -0.016, -0.011, -0.006, -0.023, 0.044, 0.044, 0.042, 0.040, -0.038, -0.036, -0.034]
k_4 = [0.003, 0.018, -0.017, -0.015, -0.014, 0.001, -0.005, -0.010, -0.019, -0.031, -0.062, -0.011, -0.010, -0.007, -0.005, 0.003, 0.002, 0.000]
k_7 = [0.008, 0.026, -0.028, -0.033, -0.039, 0.011, -0.025, -0.024, -0.028, -0.033, -0.029, 0.011, 0.012, 0.013, 0.015, -0.017, -0.019, -0.020]
k_10 = [0.010, 0.022, -0.025, -0.026, -0.023, 0.010, -0.032, -0.032, -0.029, -0.026, -0.028, -0.001, -0.001, -0.002, -0.003, 0.004, 0.005, 0.004]

# %%
x = np.arange(len(labels))  # the label locations
#x = [ 1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52]

width = 0.15  # the width of the bars


fig, ax = plt.subplots(figsize=(30, 22.5))
rects1 = ax.bar(x - (3*width/2), k_1, width, label='k=1', color ='grey')
rects2 = ax.bar(x - (width/2), k_4, width, label='k=4')
rects3 = ax.bar(x + (width/2), k_7, width, label='k=7')
rects4 = ax.bar(x + (3*width/2), k_10, width, label='k=10', color ='purple')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Change in prediction accuracy', fontsize=22)
#ax.set_title('Accuracy increase/decrease going from 186 machine to 206 machine for each NP in T18', fontsize=30)
ax.set_ylim([-0.07, 0.07])
ax.set_xticks(x)

ax.set_xticklabels(labels, fontsize=30)

ax.legend(fontsize=20)


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


#autolabel(rects1)
#autolabel(rects2)

fig.tight_layout()

plt.show()
plt.savefig('Fig6.pdf', transparent=True, format='pdf', bbox_inches='tight')
